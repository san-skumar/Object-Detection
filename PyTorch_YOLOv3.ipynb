# %% [markdown]
# <a href="https://colab.research.google.com/github/san-skumar/Object-Detection/blob/main/PyTorch_YOLOv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount th google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Yolo/pytorch-yolo-v3'
# !ls
# Out:
# /content/drive/MyDrive/Yolo/pytorch-yolo-v3
# bbox.py      data		imgs	       __pycache__  video_demo_half.py
# cam_demo.py  detect.py		__init__.py    README.md    video_demo.py
# cfg	     det_messi.jpg	pallete        test.txt
# darknet.py   dog-cycle-car.png	preprocess.py  util.py

# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5940, done.
# remote: Total 5940 (delta 0), reused 0 (delta 0), pack-reused 5940
# Receiving objects: 100% (5940/5940), 6.34 MiB | 5.36 MiB/s, done.
# Resolving deltas: 100% (3941/3941), done.
# Checking out files: 100% (979/979), done.

# %%
# !git clone https://github.com/ayooshkathuria/pytorch-yolo-v3
# Out:
# Cloning into 'pytorch-yolo-v3'...
# remote: Enumerating objects: 490, done.
# remote: Total 490 (delta 0), reused 0 (delta 0), pack-reused 490
# Receiving objects: 100% (490/490), 2.40 MiB | 14.70 MiB/s, done.
# Resolving deltas: 100% (302/302), done.

# %%
# !python detect.py --images /content/drive/MyDrive/Yolo/SurgicalDataset/Images/Fourclassesseparate/separado98.jpg
# Out:
# Loading network.....
# Network successfully loaded
# separado98.jpg       predicted in  0.181 seconds
# Objects Detected:    Scalpel nº4 Straight Mayo Scissor Straight Mayo Scissor
# ----------------------------------------------------------
#
# SUMMARY
# ----------------------------------------------------------
# Task                     : Time Taken (in seconds)
#
# Reading addresses        : 1.203
# Loading batch            : 0.853
# Detection (1 images)     : 0.203
# Output Processing        : 0.000
# Drawing Boxes            : 1.142
# Average time_per_img     : 2.474
# ----------------------------------------------------------

# %%
# !python video_demo.py --video /content/drive/MyDrive/Yolo/tool.avi
# Out:
# Loading network.....
# Network successfully loaded
# tensor([0.0000e+00, 3.4233e+01, 1.1056e+02, 2.2057e+02, 6.5376e+02, 5.7711e-01,
#         9.9690e-01, 0.0000e+00], device='cuda:0')
# tensor([  0.0000, 317.6300, 129.7928, 737.1134, 470.6653,   0.9244,   0.8083,
#           2.0000], device='cuda:0')
# tensor([0.0000e+00, 3.7782e+01, 1.0952e+02, 2.1816e+02, 6.5972e+02, 6.1083e-01,
#         9.9721e-01, 0.0000e+00], device='cuda:0')
# tensor([0.0000e+00, 3.1836e+02, 1.4966e+02, 7.2038e+02, 5.0331e+02, 7.4442e-01,
#         5.2523e-01, 1.0000e+00], device='cuda:0')
# tensor([  0.0000, 317.4154, 132.9620, 721.0474, 468.5815,   0.9125,   0.7797,
#           2.0000], device='cuda:0')
# tensor([0.0000e+00, 3.5012e+01, 1.1042e+02, 2.2160e+02, 6.5213e+02, 5.1171e-01,
#         9.9516e-01, 0.0000e+00], device='cuda:0')
# tensor([  0.0000, 334.2573, 140.3674, 697.4067, 461.3324,   0.9422,   0.8342,
#           2.0000], device='cuda:0')
# ...

# %%
# !python cam_demo.py
# Out:
# VIDEOIO ERROR: V4L: can't find camera device
# Traceback (most recent call last):
#   File "cam_demo.py", line 108, in <module>
#     assert cap.isOpened(), 'Cannot capture source'
# AssertionError: Cannot capture source

# %%
classes = ['A', 'B', 'C', 'D']
cl =

# %%
"{0}".format()
